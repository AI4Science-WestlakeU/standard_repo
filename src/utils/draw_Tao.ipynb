# %%
results_path='/zhangtao/project2024/test/diffusion_operator/results/draw_super_resolution/'
fontsize=20
width=8
fontsize_legend=16

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
methods = [
    'WDNO(linear)',
    'FNO(linear)',
    'WDNO(nearest)',
    'FNO(nearest)'
]

upsampling_numbers = [0, 1, 2, 3]

mse_values = {
    'WDNO(linear)': [0.00258772, 0.0007429, 0.00035643, 0.00035312],
    # 'FNO(linear)': [0.028467924, 0.042703645, 0.05017411, 0.05408379],
    'FNO(linear)': [0.00229724,0.0305359,0.04891477,0.05874636],
    'WDNO(nearest)': [0.00381964, 0.00110175, 0.00045733, 0.00035312],
    # 'FNO(nearest)': [0.02918883, 0.0432552, 0.05047121, 0.05412094]
    'FNO(nearest)': [0.00274577,0.03154994,0.04946154,0.05883549]
}
# Custom colors
# colors = {
#     'WDNO(linear)': '#3682be',
#     'FNO(linear)': '#f05326',
#     'WDNO(nearest)': '#38cb7d',
#     'FNO(nearest)': '#ddae33'
# }
colors = {
    'WDNO(linear)': '#3682be',
    'FNO(linear)': '#f05326',
    'WDNO(nearest)': '#3682be',
    'FNO(nearest)': '#f05326'
}

markers = {
    'WDNO(linear)': 'o',
    'FNO(linear)': 's',
    'WDNO(nearest)': '^',
    'FNO(nearest)': 'd'
}

linestyles = {
    'WDNO(linear)': '-',
    'FNO(linear)': '-',
    'WDNO(nearest)': '--',
    'FNO(nearest)': '--'
}
# Convert MSE values to log scale
log_mse_values = {method: np.log(values) for method, values in mse_values.items()}

# Plotting
plt.figure(figsize=(width, 6))

for method, log_values in log_mse_values.items():
    plt.plot(upsampling_numbers, log_values, marker=markers[method], label=method, color=colors[method], linestyle=linestyles[method])

plt.xlabel('Number of Upsampling',fontsize=fontsize)
plt.ylabel('Log(MSE)',fontsize=fontsize)
plt.xticks(upsampling_numbers, fontsize=fontsize_legend)
plt.yticks([-9,-7,-5,-3,-1],fontsize=fontsize_legend)
plt.ylim([-9, -1])
plt.legend(fontsize=fontsize_legend, ncol=2)
plt.grid(False)

# Save the plot as PDF
plt.savefig(results_path+'MSE_1d_super_resolution1.pdf',bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the updated table
methods = [
    'DDPM(linear)',
    'WDNO(linear)',
    'DDPM(nearest)',
    'WDNO(nearest)'
]

upsampling_numbers = [0, 1, 2, 3]

mse_values = {
    'DDPM(linear)': [0.002447461, 0.00064145, 0.00037541, 0.00063513],
    'WDNO(linear)': [0.00258772, 0.0007429, 0.00035643, 0.00035312],
    'DDPM(nearest)': [0.00367692, 0.00102739, 0.0006175, 0.00063513],
    'WDNO(nearest)': [0.00381964, 0.00110175, 0.00045733, 0.00035312]
}

# Custom colors
colors = {
    'DDPM(linear)': '#844bb3',
    'WDNO(linear)': '#3682be',
    'DDPM(nearest)': '#844bb3',
    'WDNO(nearest)': '#3682be'
}
markers = {
    'DDPM(linear)': '*',
    'WDNO(linear)': 'o',
    'DDPM(nearest)': 'p',
    'WDNO(nearest)': '^'
}
linestyles = {
    'DDPM(linear)': '-',
    'WDNO(linear)': '-',
    'DDPM(nearest)': '--',
    'WDNO(nearest)': '--'
}
# Convert MSE values to log scale
log_mse_values = {method: np.log(values) for method, values in mse_values.items()}

# Plotting without grid and with bold axis labels
plt.figure(figsize=(width, 6))

for method, log_values in log_mse_values.items():
    plt.plot(upsampling_numbers, log_values, marker=markers[method], label=method, color=colors[method], linestyle=linestyles[method])

plt.xlabel('Number of Upsampling',fontsize=fontsize)
plt.ylabel('Log(MSE)',fontsize=fontsize)
plt.xticks(upsampling_numbers, fontsize=fontsize_legend)
plt.yticks([-9,-7,-5,-3,-1],fontsize=fontsize_legend)
plt.legend(fontsize=fontsize_legend, ncol=2)
plt.grid(False)
plt.ylim([-9, -1])
# Save the plot as PDF
plt.savefig(results_path+'MSE_1d_super_resolution2.pdf',bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the updated table
methods = [
    'WDNO(linear)',
    'FNO(linear)',
    'WDNO(nearest)',
    'FNO(nearest)'
]

upsampling_numbers = [0, 1]

mse_values = {
    'WDNO(linear)': [0.09309284, 0.00764771],
    # 'FNO(linear)': [0.00657894, 0.01636332],
    'FNO(linear)': [0.15532202816009522,0.01117839141190052],
    'WDNO(nearest)': [0.12001918, 0.00764771],
    # 'FNO(nearest)': [0.00954193, 0.01636332]
    'FNO(nearest)': [0.1997799243927002,0.01117839141190052]
}

# Custom colors
# Custom colors
# colors = {
#     'WDNO(linear)': '#3682be',
#     'FNO(linear)': '#f05326',
#     'WDNO(nearest)': '#38cb7d',
#     'FNO(nearest)': '#ddae33'
# }
colors = {
    'WDNO(linear)': '#3682be',
    'FNO(linear)': '#f05326',
    'WDNO(nearest)': '#3682be',
    'FNO(nearest)': '#f05326'
}
# Different markers for each method
markers = {
    'WDNO(linear)': 'o',
    'FNO(linear)': 's',
    'WDNO(nearest)': '^',
    'FNO(nearest)': 'd'
}

linestyles = {
    'WDNO(linear)': '-',
    'FNO(linear)': '-',
    'WDNO(nearest)': '--',
    'FNO(nearest)': '--'
}
# Convert MSE values to log scale
log_mse_values = {method: np.log(values) for method, values in mse_values.items()}

# Plotting without grid and with bold axis labels
plt.figure(figsize=(width, 6))

for method, log_values in log_mse_values.items():
    plt.plot(upsampling_numbers, log_values, marker=markers[method],linestyle=linestyles[method], label=method, color=colors[method])

plt.xlabel('Number of Upsampling', fontsize=fontsize)
plt.ylabel('Log(MSE)', fontsize=fontsize)
plt.xticks(upsampling_numbers, fontsize=fontsize_legend)
plt.yticks([-6,-4,-2,0], fontsize=fontsize_legend)
plt.legend(fontsize=fontsize_legend, ncol=2)
plt.grid(False)
plt.ylim([-6, 0])
# Save the plot as PDF
plt.savefig(results_path+'MSE_2d_super_resolution.pdf',bbox_inches='tight')
plt.show()
